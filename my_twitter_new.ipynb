# %% [markdown]
# ## project

# %% [markdown]
# #### This is a program to get the list of tweets with the given hashtag.

# %%
from requests_oauthlib import OAuth1Session
import json
import datetime, time, sys
import key


key_words = input('This is a program to get the list of tweets with the given hashtag \n\
Please enter a hashtag\n(You can start by #,the number of tweets limited to 30)')
print('The hashtag you entered:',key_words)


session = OAuth1Session(key.CK, key.CS, key.AT, key.AS)
url = 'https://api.twitter.com/1.1/search/tweets.json'

try:
    res = session.get(url, params = {'q':key_words, 'count':30,'until',})

    if res.status_code != 200:
        print ("Twitter API Error: %d" % res.status_code)
        sys.exit(1)

    print('Accessible times %s' % res.headers['X-Rate-Limit-Remaining'])
    print('Reset time %s' % res.headers['X-Rate-Limit-Reset'])
    sec =int(res.headers['X-Rate-Limit-Reset'])\
               - time.mktime(datetime.datetime.now().timetuple())
    print('Reset time （Convert to remaining seconds） %s' % sec)


    res_text = json.loads(res.text)
    for tweet in res_text['statuses']:
        print('---------------------------------------------------------------------------')
        print('account:',"(fullname:",tweet['user']['name'],'href:',("/"+tweet['user']['screen_name']).strip(),"id:",tweet['user']['id'],')')
        print("date:",tweet['created_at'])
        print("hashtags:",key_words)
        print(tweet['favorite_count'])
        print(tweet['retweet_count'])
        print (tweet['text'])
except:
    print("Can't find the hashtag or can't connect to internet")
# Out:
# This is a program to get the list of tweets with the given hashtag
# Please enter a hashtag
# (You can start by #,the number of tweets limited to 30)#python
# The hashtag you entered: #python
# Accessible times 172
# Reset time 1542198566
# Reset time （Convert to remaining seconds） 205.0
# ---------------------------------------------------------------------------
# account: (fullname: Mohit Bajoria href: /mbj36 id: 3140110765 )
# date: Wed Nov 14 12:25:40 +0000 2018
# hashtags: #python
# 0
# 2
# RT @joinindorse: 🆕 Dev Update  —  14 November 2018
#
# Our quest for the holy grail of mainstream adoption and our first successes! 🚀
# Are you…
# ---------------------------------------------------------------------------
# account: (fullname: Data Flair href: /DataFlairWS id: 2897266280 )
# date: Wed Nov 14 12:25:19 +0000 2018
# hashtags: #python
# 0
# 0
# #Python sys Module – Important Functions
# #MachineLearning #Analytics #DataAnalytics #DataScience #DataScientist… https://t.co/KiW1dYz0BZ
# ---------------------------------------------------------------------------
# account: (fullname: Laksamana Yuda C H href: /Handika_Salman id: 265849418 )
# date: Wed Nov 14 12:24:37 +0000 2018
# hashtags: #python
# 0
# 8
# RT @SeattleDataGuy: Practical Data Science Teams - Data Consulting #datascience #bigdata #machinelearning #ai #ml #data #tech #aws #cloud #…
# ---------------------------------------------------------------------------
# account: (fullname: Web Developer Jobs href: /WebDevJobsNow id: 927245875751112704 )
# date: Wed Nov 14 12:24:14 +0000 2018
# hashtags: #python
# 0
# 1
# RT @London__Digital: #LondonDigital Hot Job!
#
# #recruitment #Careers #Jobs #hiring #londonjobs #Banking #InvestmentBanking #financialmarkets…
# ---------------------------------------------------------------------------
# account: (fullname: Riverdi href: /riverdidisplays id: 3378616361 )
# date: Wed Nov 14 12:23:58 +0000 2018
# hashtags: #python
# 0
# 0
# As promised - the new #Python programmable #Riverdi displays at the @electronicaFair in Munich.
#
# Read more:… https://t.co/0vtgUnTtqV
# ---------------------------------------------------------------------------
# account: (fullname: 🤖 #100DAYSOFCODE href: /100xcode id: 1000814755664150528 )
# date: Wed Nov 14 12:23:32 +0000 2018
# hashtags: #python
# 0
# 1
# RT @jatinchauhannn: Day1:
# Introduction to Artificial Intelligence and fundamentals of reinforcement learning
#
# #100DaysOfCode #ArtificialInt…
# ---------------------------------------------------------------------------
# account: (fullname: Jatin href: /jatinchauhannn id: 551772155 )
# date: Wed Nov 14 12:23:26 +0000 2018
# hashtags: #python
# 1
# 1
# Day1:
# Introduction to Artificial Intelligence and fundamentals of reinforcement learning
#
# #100DaysOfCode #ArtificialIntelligence #AI #python
# ---------------------------------------------------------------------------
# account: (fullname: Bob Belderbos href: /bbelderbos id: 177360544 )
# date: Wed Nov 14 12:23:13 +0000 2018
# hashtags: #python
# 0
# 0
# Day 08: #100DaysOfAosa progress: today I read 📘 500 Lines Or Less till p.120 (logged via @pybites… https://t.co/rUqyqxZNnn
# ---------------------------------------------------------------------------
# account: (fullname: Infotel href: /Infotel_ id: 551729884 )
# date: Wed Nov 14 12:22:45 +0000 2018
# hashtags: #python
# 0
# 0
# Être Ingénieur Études et Développement chez Infotel, c'est :
# 🔥 Être passionné par son métier
# 🤲 Avoir un management… https://t.co/k2WUqCg8ac
# ---------------------------------------------------------------------------
# account: (fullname: Bob Belderbos href: /bbelderbos id: 177360544 )
# date: Wed Nov 14 12:22:23 +0000 2018
# hashtags: #python
# 0
# 0
# Day 07: #100DaysOfAosa progress: today I read 📘 500 Lines Or Less till p.105 (logged via @pybites https://t.co/ILXzDTTnUz) #Python
# ---------------------------------------------------------------------------
# account: (fullname: Bob Belderbos href: /bbelderbos id: 177360544 )
# date: Wed Nov 14 12:22:06 +0000 2018
# hashtags: #python
# 0
# 0
# Day 06: #100DaysOfAosa progress: today I read 📘 500 Lines Or Less till p.90 (logged via @pybites https://t.co/ILXzDTTnUz) #Python
# ---------------------------------------------------------------------------
# account: (fullname: cyborg href: /AkoSasori id: 404143286 )
# date: Wed Nov 14 12:21:29 +0000 2018
# hashtags: #python
# 0
# 1
# Most tech firms don't actually practice #Agile development, what they have is pressure development represented as a… https://t.co/SeuYGUGTVc
# ---------------------------------------------------------------------------
# account: (fullname: Dr. Peter Selby href: /drpselby id: 4152945665 )
# date: Wed Nov 14 12:20:52 +0000 2018
# hashtags: #python
# 0
# 2
# RT @achauschild: The CAMH scientific computing group is organizing workshops on Fundamentals for Researchers! I am honored to contribute a…
# ---------------------------------------------------------------------------
# account: (fullname: Ardèch'Drôm Dev href: /ArdechDromDev id: 913498061099425792 )
# date: Wed Nov 14 12:20:08 +0000 2018
# hashtags: #python
# 0
# 4
# RT @DjangoGirlsFr26: 🦄🦄 Les inscriptions sont ouvertes 🦄🦄
# https://t.co/jYOCUsaU0m
# Venez au @CampusAlps découvrir la programmation et créer…
# ---------------------------------------------------------------------------
# account: (fullname: Cool Go href: /cool_golang id: 735555667965136897 )
# date: Wed Nov 14 12:20:04 +0000 2018
# hashtags: #python
# 0
# 2
# RT @Jemmagrubb1: We provide security feedback directly in your GitHub pull requests. Supporting #ruby #golang #solidity #nodejs #python! #d…
# ---------------------------------------------------------------------------
# account: (fullname: Gamer Geek href: /GamerGeekNews id: 316331833 )
# date: Wed Nov 14 12:20:03 +0000 2018
# hashtags: #python
# 0
# 1
# RT @omegaki113r: #vuejs #programmer #coderlife #womenwhocode #java #python #javascript #csharp #cplusplus #django #webdeveloper #webdesign…
# ---------------------------------------------------------------------------
# account: (fullname: GentooBot href: /GentooBot id: 924173288409939968 )
# date: Wed Nov 14 12:19:49 +0000 2018
# hashtags: #python
# 0
# 3
# RT @ProgrammerBooks: Essential PowerShell for Office 365 [PDF] : https://t.co/ordAft7Hc1
# #python #javascript #angular #angularjs #reactjs #…
# ---------------------------------------------------------------------------
# account: (fullname: Omegaki113r href: /omegaki113r id: 1049270661464580096 )
# date: Wed Nov 14 12:19:20 +0000 2018
# hashtags: #python
# 0
# 1
# #vuejs #programmer #coderlife #womenwhocode #java #python #javascript #csharp #cplusplus #django #webdeveloper… https://t.co/zpLUwn3TvI
# ---------------------------------------------------------------------------
# account: (fullname: DIGITALSPHERE href: /digitalsphere33 id: 900671288687177728 )
# date: Wed Nov 14 12:19:18 +0000 2018
# hashtags: #python
# 0
# 2
# RT @omegaki113r: #vuejs #programmer #coderlife #womenwhocode #java #python #javascript #csharp #cplusplus #django #webdeveloper #webdesign…
# ---------------------------------------------------------------------------
# account: (fullname: DIGITALSPHERE href: /digitalsphere33 id: 900671288687177728 )
# date: Wed Nov 14 12:19:16 +0000 2018
# hashtags: #python
# 0
# 3
# RT @ProgrammerBooks: Essential PowerShell for Office 365 [PDF] : https://t.co/ordAft7Hc1
# #python #javascript #angular #angularjs #reactjs #…
# ---------------------------------------------------------------------------
# account: (fullname: Vishnu Priya href: /vishn_u99 id: 1035175128273838080 )
# date: Wed Nov 14 12:19:15 +0000 2018
# hashtags: #python
# 0
# 1
# RT @omegaki113r: What is your #weapons My one is #Java #vuejs #programmer #coderlife #womenwhocode #java #python #javascript #csharp #cplus…
# ---------------------------------------------------------------------------
# account: (fullname: Cameron Laird href: /Phaseit id: 270659441 )
# date: Wed Nov 14 12:18:57 +0000 2018
# hashtags: #python
# 0
# 16
# RT @raymondh: macOS #Python development issue: A few days ago, I accepted an XCode update.  Since then, I haven't been able to build Python…
# ---------------------------------------------------------------------------
# account: (fullname: Programmer Books href: /ProgrammerBooks id: 992142356420980738 )
# date: Wed Nov 14 12:18:35 +0000 2018
# hashtags: #python
# 1
# 3
# Essential PowerShell for Office 365 [PDF] : https://t.co/ordAft7Hc1
# #python #javascript #angular #angularjs… https://t.co/g69c12pvLH
# ---------------------------------------------------------------------------
# account: (fullname: Indorse News href: /IndorseNews id: 905673664594452480 )
# date: Wed Nov 14 12:18:07 +0000 2018
# hashtags: #python
# 0
# 0
# #INDORSE: 🆕 Dev Update  —  14 November 2018
#
# Our quest for the holy grail of mainstream adoption and our first succ… https://t.co/8BQNrgGVZa
# ---------------------------------------------------------------------------
# account: (fullname: Peter Python href: /Pythondevelopm2 id: 1053011875007483905 )
# date: Wed Nov 14 12:18:00 +0000 2018
# hashtags: #python
# 0
# 7
# RT @AIApparelStore: Word(s) of the day: Artificial Intelligence. Check out our apparel!! #datascience #artificialintelligence #machinelearn…
# ---------------------------------------------------------------------------
# account: (fullname: Peter Python href: /Pythondevelopm2 id: 1053011875007483905 )
# date: Wed Nov 14 12:17:55 +0000 2018
# hashtags: #python
# 0
# 2
# RT @geo_university: 🎉Happy #GISday!🌐
# What a great way to celebrate it with a #brandnew GIS course! "Geospatial Analysis for Urban Applicati…
# ---------------------------------------------------------------------------
# account: (fullname: Peter Python href: /Pythondevelopm2 id: 1053011875007483905 )
# date: Wed Nov 14 12:17:55 +0000 2018
# hashtags: #python
# 0
# 2
# RT @Jemmagrubb1: We provide security feedback directly in your GitHub pull requests. Supporting #ruby #golang #solidity #nodejs #python! #d…
# ---------------------------------------------------------------------------
# account: (fullname: Peter Python href: /Pythondevelopm2 id: 1053011875007483905 )
# date: Wed Nov 14 12:17:54 +0000 2018
# hashtags: #python
# 0
# 2
# RT @joinindorse: 🆕 Dev Update  —  14 November 2018
#
# Our quest for the holy grail of mainstream adoption and our first successes! 🚀
# Are you…
# ---------------------------------------------------------------------------
# account: (fullname: HTML href: /html_css_bot id: 769629395262771200 )
# date: Wed Nov 14 12:16:26 +0000 2018
# hashtags: #python
# 0
# 2
# RT @omegaki113r: #vuejs #programmer #coderlife #womenwhocode #java #python #javascript #csharp #cplusplus #django #webdeveloper #webdesign…
# ---------------------------------------------------------------------------
# account: (fullname: Indorse href: /joinindorse id: 861463172296974336 )
# date: Wed Nov 14 12:16:02 +0000 2018
# hashtags: #python
# 1
# 2
# 🆕 Dev Update  —  14 November 2018
#
# Our quest for the holy grail of mainstream adoption and our first successes! 🚀
# A… https://t.co/zWEUVpNKrq

# %% [markdown]
# #### This is a program to get the list of tweets that user has on his feed in json format.

# %%
import tweepy
import key

key_words = input('This is a program to get the list of tweets that user has\n\
Please enter a user screen name\n(You can start by @,the number of tweets limited to 30)')
print('The user screen name you entered:',key_words)

consumer_key = key.CK
consumer_secret = key.CS
access_key = key.AT
access_secret = key.AS

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)
try:
    for tweet in tweepy.Cursor(api.user_timeline,screen_name = key_words).items(30):
        print('---------------------------------------------------------------------------')
        print('full_name:',tweet.user.name,"href:",("/"+tweet.user.screen_name).strip(),"id:",tweet.user.id)
        print("date:",tweet.created_at)
        if tweet.entities['hashtags'] ==[]:
            print('None')
        else:
            print(tweet.entities['hashtags'][0]['text'])
        print(tweet.favorite_count)
        print(tweet.retweet_count)
        print(tweet.text.replace('\n',''))
except:
    print("Can't find the user or can't connect to internet")
# Out:
# This is a program to get the list of tweets that user has
# Please enter a user screen name
# (You can start by @,the number of tweets limited to 30)@twitter
# The user screen name you entered: @twitter
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-14 00:26:21
# None
# 75
# 3
# @ny_gal10 😎
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-14 00:10:41
# None
# 544
# 11
# @ohaniceyt That happened
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-14 00:07:57
# None
# 329
# 17
# @WaitThatsAdam https://t.co/yR23g0RsGD
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-14 00:06:57
# None
# 14238
# 2126
# A subtweet
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 15:02:35
# ForTheThrone
# 12415
# 3483
# ==(_____________________________)==         |          It's time to Tweet           |       #ForTheThrone… https://t.co/ailAW8ZQGu
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:05:53
# None
# 23
# 0
# @DisIsBuck Do it
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:05:32
# None
# 3
# 0
# @a_nice_frog Logging in when you're logged in
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:05:12
# None
# 2352
# 223
# @C_millz6 Stay on Twitter and you'll never have to answer the text
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:04:50
# None
# 10
# 1
# @brookemiccio We really do love that
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:04:31
# None
# 9
# 4
# @kamz26 Twitter friends are forever friends
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:04:13
# None
# 9
# 1
# @TheEmekaDiala 100%
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:03:54
# None
# 87
# 13
# @Biisi96 Strangers ➡️ friends in a Twitter minute
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:03:33
# None
# 11
# 0
# @taramassicotte Close enough
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:03:13
# None
# 3
# 1
# @Cute_Olodo_NG Gotta Tweet it earlier next time
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-13 00:02:46
# None
# 14
# 1
# @tonytx4_ They're a staple
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 20:32:15
# None
# 111
# 31
# @Dictionarycom 👆
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 19:09:19
# None
# 5
# 0
# @SuperRetina Carpe diem
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 19:01:16
# None
# 7
# 1
# @Mizz_Mary_Mac https://t.co/nuwDD2b6mV
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:47:52
# None
# 4
# 1
# @RPSashaBanksWWE So meta
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:31:07
# None
# 192
# 4
# @NishwanAbbas @waddey Or is it that other thing?
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:10:16
# None
# 355
# 6
# @anche_meno Like you did last summer
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:06:22
# None
# 612
# 34
# @usernameisdean What's your patronus?
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 18:04:22
# None
# 662
# 15
# @big_benford Nope, talking to you
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-12 17:59:55
# None
# 45586
# 7927
# Twitter, do your thing.
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:27:32
# None
# 16
# 0
# @HeartEyes4Brady Hi 💙
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:27:09
# None
# 26
# 0
# @BloodRedLiqueur What'd you find?
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:26:49
# None
# 410
# 3
# @TaliaMar Sunscreen
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:26:29
# None
# 12
# 2
# @fessyfitness Shady is a lifestyle
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:26:05
# None
# 66
# 7
# @majornelson He looks like this                          😶                         \    /… https://t.co/WFjOYH4r16
# ---------------------------------------------------------------------------
# full_name: Twitter href: /Twitter id: 783214
# date: 2018-11-09 22:25:42
# None
# 66
# 5
# @Hampton Nothing more than 280 characters
